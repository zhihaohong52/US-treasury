# %%
import requests
from pprint import pprint

url = 'https://eservices.mas.gov.sg/api/action/datastore/search.json?resource_id=ec2cb157-d25f-4245-a547-dc036b321a09'

response = requests.get(url)
pprint(response.json())
# Out:
# {'result': {'limit': 100,
#             'records': [{'end_of_quarter': '1991-Q1',
#                          'issue_bonds': '1050',
#                          'issue_tbills': '2410',
#                          'outstand_bonds': '7660',
#                          'outstand_tbills': '2710',
#                          'preliminary': '0',
#                          'redempt_bonds': '0',
#                          'redempt_tbills': '1770',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '1991-Q2',
#                          'issue_bonds': '450',
#                          'issue_tbills': '2200',
#                          'outstand_bonds': '7610',
#                          'outstand_tbills': '2950',
#                          'preliminary': '0',
#                          'redempt_bonds': '500',
#                          'redempt_tbills': '1960',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '1991-Q3',
#                          'issue_bonds': '800',
#                          'issue_tbills': '2290',
#                          'outstand_bonds': '7710',
#                          'outstand_tbills': '3190',
#                          'preliminary': '0',
#                          'redempt_bonds': '700',
#                          'redempt_tbills': '2050',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '1991-Q4',
#                          'issue_bonds': '0',
#                          'issue_tbills': '2660',
#                          'outstand_bonds': '7710',
#                          'outstand_tbills': '3470',
#                          'preliminary': '0',
#                          'redempt_bonds': '0',
#                          'redempt_tbills': '2380',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '1992-Q1',
#                          'issue_bonds': '850',
#                          'issue_tbills': '3210',
#                          'outstand_bonds': '7910',
#                          'outstand_tbills': '3920',
#                          'preliminary': '0',
#                          'redempt_bonds': '650',
#                          'redempt_tbills': '2760',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '1992-Q2',
#                          'issue_bonds': '700',
#                          'issue_tbills': '2800',
#                          'outstand_bonds': '8110',
#                          'outstand_tbills': '4170',
#                          'preliminary': '0',
#                          'redempt_bonds': '500',
#                          'redempt_tbills': '2550',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '1992-Q3',
#                          'issue_bonds': '700',
#                          'issue_tbills': '3940',
#                          'outstand_bonds': '8510',
#                          'outstand_tbills': '4940',
#                          'preliminary': '0',
#                          'redempt_bonds': '300',
#                          'redempt_tbills': '3170',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '1992-Q4',
#                          'issue_bonds': '1450',
#                          'issue_tbills': '3940',
#                          'outstand_bonds': '8760',
#                          'outstand_tbills': '4940',
#                          'preliminary': '0',
#                          'redempt_bonds': '1200',
#                          'redempt_tbills': '3940',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '1993-Q1',
#                          'issue_bonds': '830',
#                          'issue_tbills': '3520',
#                          'outstand_bonds': '9060',
#                          'outstand_tbills': '4720',
#                          'preliminary': '0',
#                          'redempt_bonds': '530',
#                          'redempt_tbills': '3740',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '1993-Q2',
#                          'issue_bonds': '550',
#                          'issue_tbills': '3890',
#                          'outstand_bonds': '9610',
#                          'outstand_tbills': '4590',
#                          'preliminary': '0',
#                          'redempt_bonds': '0',
#                          'redempt_tbills': '4020',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '1993-Q3',
#                          'issue_bonds': '1350',
#                          'issue_tbills': '4990',
#                          'outstand_bonds': '9930',
#                          'outstand_tbills': '4690',
#                          'preliminary': '0',
#                          'redempt_bonds': '1030',
#                          'redempt_tbills': '4890',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '1993-Q4',
#                          'issue_bonds': '530',
#                          'issue_tbills': '3810',
#                          'outstand_bonds': '10460',
#                          'outstand_tbills': '4990',
#                          'preliminary': '0',
#                          'redempt_bonds': '0',
#                          'redempt_tbills': '3510',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '1994-Q1',
#                          'issue_bonds': '850',
#                          'issue_tbills': '4220',
#                          'outstand_bonds': '10460',
#                          'outstand_tbills': '5050',
#                          'preliminary': '0',
#                          'redempt_bonds': '850',
#                          'redempt_tbills': '4160',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '1994-Q2',
#                          'issue_bonds': '750',
#                          'issue_tbills': '3550',
#                          'outstand_bonds': '10610',
#                          'outstand_tbills': '4960',
#                          'preliminary': '0',
#                          'redempt_bonds': '600',
#                          'redempt_tbills': '3640',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '1994-Q3',
#                          'issue_bonds': '800',
#                          'issue_tbills': '4240',
#                          'outstand_bonds': '11410',
#                          'outstand_tbills': '4540',
#                          'preliminary': '0',
#                          'redempt_bonds': '0',
#                          'redempt_tbills': '4660',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '1994-Q4',
#                          'issue_bonds': '1350',
#                          'issue_tbills': '4120',
#                          'outstand_bonds': '11110',
#                          'outstand_tbills': '5000',
#                          'preliminary': '0',
#                          'redempt_bonds': '1650',
#                          'redempt_tbills': '3660',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '1995-Q1',
#                          'issue_bonds': '1050',
#                          'issue_tbills': '5110',
#                          'outstand_bonds': '12160',
#                          'outstand_tbills': '5110',
#                          'preliminary': '0',
#                          'redempt_bonds': '0',
#                          'redempt_tbills': '5000',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '1995-Q2',
#                          'issue_bonds': '800',
#                          'issue_tbills': '4670',
#                          'outstand_bonds': '12410',
#                          'outstand_tbills': '5790',
#                          'preliminary': '0',
#                          'redempt_bonds': '550',
#                          'redempt_tbills': '3990',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '1995-Q3',
#                          'issue_bonds': '1750',
#                          'issue_tbills': '4790',
#                          'outstand_bonds': '12210',
#                          'outstand_tbills': '5790',
#                          'preliminary': '0',
#                          'redempt_bonds': '1950',
#                          'redempt_tbills': '4790',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '1995-Q4',
#                          'issue_bonds': '600',
#                          'issue_tbills': '5400',
#                          'outstand_bonds': '12810',
#                          'outstand_tbills': '5750',
#                          'preliminary': '0',
#                          'redempt_bonds': '0',
#                          'redempt_tbills': '5440',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '1996-Q1',
#                          'issue_bonds': '1350',
#                          'issue_tbills': '5310',
#                          'outstand_bonds': '13510',
#                          'outstand_tbills': '6100',
#                          'preliminary': '0',
#                          'redempt_bonds': '650',
#                          'redempt_tbills': '4960',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '1996-Q2',
#                          'issue_bonds': '500',
#                          'issue_tbills': '5430',
#                          'outstand_bonds': '14010',
#                          'outstand_tbills': '5990',
#                          'preliminary': '0',
#                          'redempt_bonds': '0',
#                          'redempt_tbills': '5540',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '1996-Q3',
#                          'issue_bonds': '1400',
#                          'issue_tbills': '5300',
#                          'outstand_bonds': '14110',
#                          'outstand_tbills': '6300',
#                          'preliminary': '0',
#                          'redempt_bonds': '1300',
#                          'redempt_tbills': '4990',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '1996-Q4',
#                          'issue_bonds': '900',
#                          'issue_tbills': '5210',
#                          'outstand_bonds': '14510',
#                          'outstand_tbills': '5990',
#                          'preliminary': '0',
#                          'redempt_bonds': '500',
#                          'redempt_tbills': '5520',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '1997-Q1',
#                          'issue_bonds': '0',
#                          'issue_tbills': '5360',
#                          'outstand_bonds': '14510',
#                          'outstand_tbills': '6580',
#                          'preliminary': '0',
#                          'redempt_bonds': '0',
#                          'redempt_tbills': '4770',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '1997-Q2',
#                          'issue_bonds': '1630',
#                          'issue_tbills': '5600',
#                          'outstand_bonds': '14690',
#                          'outstand_tbills': '6520',
#                          'preliminary': '0',
#                          'redempt_bonds': '1450',
#                          'redempt_tbills': '5660',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '1997-Q3',
#                          'issue_bonds': '980',
#                          'issue_tbills': '4990',
#                          'outstand_bonds': '14720',
#                          'outstand_tbills': '6690',
#                          'preliminary': '0',
#                          'redempt_bonds': '950',
#                          'redempt_tbills': '4820',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '1997-Q4',
#                          'issue_bonds': '850',
#                          'issue_tbills': '6540',
#                          'outstand_bonds': '14970',
#                          'outstand_tbills': '6920',
#                          'preliminary': '0',
#                          'redempt_bonds': '600',
#                          'redempt_tbills': '6310',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '1998-Q1',
#                          'issue_bonds': '1100',
#                          'issue_tbills': '5640',
#                          'outstand_bonds': '15520',
#                          'outstand_tbills': '7690',
#                          'preliminary': '0',
#                          'redempt_bonds': '550',
#                          'redempt_tbills': '4870',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '1998-Q2',
#                          'issue_bonds': '700',
#                          'issue_tbills': '7100',
#                          'outstand_bonds': '16220',
#                          'outstand_tbills': '8010',
#                          'preliminary': '0',
#                          'redempt_bonds': '0',
#                          'redempt_tbills': '6780',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '1998-Q3',
#                          'issue_bonds': '4250',
#                          'issue_tbills': '6530',
#                          'outstand_bonds': '18340',
#                          'outstand_tbills': '8140',
#                          'preliminary': '0',
#                          'redempt_bonds': '2130',
#                          'redempt_tbills': '6400',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '1998-Q4',
#                          'issue_bonds': '1750',
#                          'issue_tbills': '8270',
#                          'outstand_bonds': '20090',
#                          'outstand_tbills': '8540',
#                          'preliminary': '0',
#                          'redempt_bonds': '0',
#                          'redempt_tbills': '7870',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '1999-Q1',
#                          'issue_bonds': '2300',
#                          'issue_tbills': '6460',
#                          'outstand_bonds': '21540',
#                          'outstand_tbills': '8860',
#                          'preliminary': '0',
#                          'redempt_bonds': '850',
#                          'redempt_tbills': '6140',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '1999-Q2',
#                          'issue_bonds': '1880',
#                          'issue_tbills': '8840',
#                          'outstand_bonds': '22570',
#                          'outstand_tbills': '9840',
#                          'preliminary': '0',
#                          'redempt_bonds': '850',
#                          'redempt_tbills': '7860',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '1999-Q3',
#                          'issue_bonds': '1900',
#                          'issue_tbills': '8740',
#                          'outstand_bonds': '22640',
#                          'outstand_tbills': '9960',
#                          'preliminary': '0',
#                          'redempt_bonds': '1830',
#                          'redempt_tbills': '8620',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '1999-Q4',
#                          'issue_bonds': '1350',
#                          'issue_tbills': '11260',
#                          'outstand_bonds': '23140',
#                          'outstand_tbills': '12160',
#                          'preliminary': '0',
#                          'redempt_bonds': '850',
#                          'redempt_tbills': '9060',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2000-Q1',
#                          'issue_bonds': '3000',
#                          'issue_tbills': '9520',
#                          'outstand_bonds': '24610',
#                          'outstand_tbills': '11720',
#                          'preliminary': '0',
#                          'redempt_bonds': '1530',
#                          'redempt_tbills': '9960',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2000-Q2',
#                          'issue_bonds': '2300',
#                          'issue_tbills': '11520',
#                          'outstand_bonds': '26210',
#                          'outstand_tbills': '12820',
#                          'preliminary': '0',
#                          'redempt_bonds': '700',
#                          'redempt_tbills': '10420',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2000-Q3',
#                          'issue_bonds': '4100',
#                          'issue_tbills': '9430',
#                          'outstand_bonds': '28010',
#                          'outstand_tbills': '12730',
#                          'preliminary': '0',
#                          'redempt_bonds': '2300',
#                          'redempt_tbills': '9520',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2000-Q4',
#                          'issue_bonds': '2700',
#                          'issue_tbills': '11380',
#                          'outstand_bonds': '29860',
#                          'outstand_tbills': '13380',
#                          'preliminary': '0',
#                          'redempt_bonds': '850',
#                          'redempt_tbills': '10730',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2001-Q1',
#                          'issue_bonds': '3900',
#                          'issue_tbills': '9730',
#                          'outstand_bonds': '32960',
#                          'outstand_tbills': '13730',
#                          'preliminary': '0',
#                          'redempt_bonds': '800',
#                          'redempt_tbills': '9380',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2001-Q2',
#                          'issue_bonds': '2600',
#                          'issue_tbills': '12350',
#                          'outstand_bonds': '33580',
#                          'outstand_tbills': '14350',
#                          'preliminary': '0',
#                          'redempt_bonds': '1980',
#                          'redempt_tbills': '11730',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2001-Q3',
#                          'issue_bonds': '4500',
#                          'issue_tbills': '10200',
#                          'outstand_bonds': '35780',
#                          'outstand_tbills': '14700',
#                          'preliminary': '0',
#                          'redempt_bonds': '2300',
#                          'redempt_tbills': '9850',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2001-Q4',
#                          'issue_bonds': '3200',
#                          'issue_tbills': '12150',
#                          'outstand_bonds': '38980',
#                          'outstand_tbills': '14650',
#                          'preliminary': '0',
#                          'redempt_bonds': '0',
#                          'redempt_tbills': '12200',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2002-Q1',
#                          'issue_bonds': '700',
#                          'issue_tbills': '10650',
#                          'outstand_bonds': '39680',
#                          'outstand_tbills': '14950',
#                          'preliminary': '0',
#                          'redempt_bonds': '0',
#                          'redempt_tbills': '10350',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2002-Q2',
#                          'issue_bonds': '1500',
#                          'issue_tbills': '13750',
#                          'outstand_bonds': '37700',
#                          'outstand_tbills': '15550',
#                          'preliminary': '0',
#                          'redempt_bonds': '3480',
#                          'redempt_tbills': '13150',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2002-Q3',
#                          'issue_bonds': '2800',
#                          'issue_tbills': '11950',
#                          'outstand_bonds': '40500',
#                          'outstand_tbills': '15950',
#                          'preliminary': '0',
#                          'redempt_bonds': '0',
#                          'redempt_tbills': '11550',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2002-Q4',
#                          'issue_bonds': '3400',
#                          'issue_tbills': '14550',
#                          'outstand_bonds': '41300',
#                          'outstand_tbills': '16750',
#                          'preliminary': '0',
#                          'redempt_bonds': '2600',
#                          'redempt_tbills': '13750',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2003-Q1',
#                          'issue_bonds': '2000',
#                          'issue_tbills': '12350',
#                          'outstand_bonds': '42600',
#                          'outstand_tbills': '16950',
#                          'preliminary': '0',
#                          'redempt_bonds': '700',
#                          'redempt_tbills': '12150',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2003-Q2',
#                          'issue_bonds': '2800',
#                          'issue_tbills': '14850',
#                          'outstand_bonds': '41900',
#                          'outstand_tbills': '17250',
#                          'preliminary': '0',
#                          'redempt_bonds': '3500',
#                          'redempt_tbills': '14550',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2003-Q3',
#                          'issue_bonds': '4000',
#                          'issue_tbills': '12000',
#                          'outstand_bonds': '45050',
#                          'outstand_tbills': '16900',
#                          'preliminary': '0',
#                          'redempt_bonds': '850',
#                          'redempt_tbills': '12350',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2003-Q4',
#                          'issue_bonds': '800',
#                          'issue_tbills': '14700',
#                          'outstand_bonds': '45850',
#                          'outstand_tbills': '17200',
#                          'preliminary': '0',
#                          'redempt_bonds': '0',
#                          'redempt_tbills': '14400',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2004-Q1',
#                          'issue_bonds': '3900',
#                          'issue_tbills': '13100',
#                          'outstand_bonds': '46750',
#                          'outstand_tbills': '18000',
#                          'preliminary': '0',
#                          'redempt_bonds': '3000',
#                          'redempt_tbills': '12300',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2004-Q2',
#                          'issue_bonds': '1300',
#                          'issue_tbills': '16800',
#                          'outstand_bonds': '44800',
#                          'outstand_tbills': '19200',
#                          'preliminary': '0',
#                          'redempt_bonds': '3250',
#                          'redempt_tbills': '15600',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2004-Q3',
#                          'issue_bonds': '6000',
#                          'issue_tbills': '15400',
#                          'outstand_bonds': '50800',
#                          'outstand_tbills': '19200',
#                          'preliminary': '0',
#                          'redempt_bonds': '0',
#                          'redempt_tbills': '15400',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2004-Q4',
#                          'issue_bonds': '2700',
#                          'issue_tbills': '17700',
#                          'outstand_bonds': '52000',
#                          'outstand_tbills': '20200',
#                          'preliminary': '0',
#                          'redempt_bonds': '1500',
#                          'redempt_tbills': '16700',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2005-Q1',
#                          'issue_bonds': '3800',
#                          'issue_tbills': '15800',
#                          'outstand_bonds': '51200',
#                          'outstand_tbills': '21100',
#                          'preliminary': '0',
#                          'redempt_bonds': '4600',
#                          'redempt_tbills': '14900',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2005-Q2',
#                          'issue_bonds': '2300',
#                          'issue_tbills': '19500',
#                          'outstand_bonds': '53500',
#                          'outstand_tbills': '22300',
#                          'preliminary': '0',
#                          'redempt_bonds': '0',
#                          'redempt_tbills': '18300',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2005-Q3',
#                          'issue_bonds': '5700',
#                          'issue_tbills': '16900',
#                          'outstand_bonds': '59200',
#                          'outstand_tbills': '22300',
#                          'preliminary': '0',
#                          'redempt_bonds': '0',
#                          'redempt_tbills': '16900',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2005-Q4',
#                          'issue_bonds': '1100',
#                          'issue_tbills': '18700',
#                          'outstand_bonds': '56700',
#                          'outstand_tbills': '21300',
#                          'preliminary': '0',
#                          'redempt_bonds': '3600',
#                          'redempt_tbills': '19700',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2006-Q1',
#                          'issue_bonds': '3500',
#                          'issue_tbills': '16400',
#                          'outstand_bonds': '57500',
#                          'outstand_tbills': '21300',
#                          'preliminary': '0',
#                          'redempt_bonds': '2700',
#                          'redempt_tbills': '16400',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2006-Q2',
#                          'issue_bonds': '2100',
#                          'issue_tbills': '21400',
#                          'outstand_bonds': '59600',
#                          'outstand_tbills': '23700',
#                          'preliminary': '0',
#                          'redempt_bonds': '0',
#                          'redempt_tbills': '19000',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2006-Q3',
#                          'issue_bonds': '3000',
#                          'issue_tbills': '20800',
#                          'outstand_bonds': '60000',
#                          'outstand_tbills': '25700',
#                          'preliminary': '0',
#                          'redempt_bonds': '2600',
#                          'redempt_tbills': '18800',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2006-Q4',
#                          'issue_bonds': '0',
#                          'issue_tbills': '23200',
#                          'outstand_bonds': '60000',
#                          'outstand_tbills': '25800',
#                          'preliminary': '0',
#                          'redempt_bonds': '0',
#                          'redempt_tbills': '23100',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2007-Q1',
#                          'issue_bonds': '4200',
#                          'issue_tbills': '23400',
#                          'outstand_bonds': '57900',
#                          'outstand_tbills': '28400',
#                          'preliminary': '0',
#                          'redempt_bonds': '6300',
#                          'redempt_tbills': '20800',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2007-Q2',
#                          'issue_bonds': '5500',
#                          'issue_tbills': '27400',
#                          'outstand_bonds': '63400',
#                          'outstand_tbills': '29800',
#                          'preliminary': '0',
#                          'redempt_bonds': '0',
#                          'redempt_tbills': '26000',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2007-Q3',
#                          'issue_bonds': '3500',
#                          'issue_tbills': '24700',
#                          'outstand_bonds': '66900',
#                          'outstand_tbills': '29900',
#                          'preliminary': '0',
#                          'redempt_bonds': '0',
#                          'redempt_tbills': '24600',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2007-Q4',
#                          'issue_bonds': '2200',
#                          'issue_tbills': '30100',
#                          'outstand_bonds': '65200',
#                          'outstand_tbills': '32900',
#                          'preliminary': '0',
#                          'redempt_bonds': '3900',
#                          'redempt_tbills': '27100',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2008-Q1',
#                          'issue_bonds': '2900',
#                          'issue_tbills': '29500',
#                          'outstand_bonds': '68100',
#                          'outstand_tbills': '35300',
#                          'preliminary': '0',
#                          'redempt_bonds': '0',
#                          'redempt_tbills': '27100',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2008-Q2',
#                          'issue_bonds': '4700',
#                          'issue_tbills': '36000',
#                          'outstand_bonds': '69000',
#                          'outstand_tbills': '39000',
#                          'preliminary': '0',
#                          'redempt_bonds': '3800',
#                          'redempt_tbills': '32300',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2008-Q3',
#                          'issue_bonds': '3800',
#                          'issue_tbills': '30500',
#                          'outstand_bonds': '68000',
#                          'outstand_tbills': '33600',
#                          'preliminary': '0',
#                          'redempt_bonds': '4800',
#                          'redempt_tbills': '35900',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2008-Q4',
#                          'issue_bonds': '700',
#                          'issue_tbills': '32800',
#                          'outstand_bonds': '68700',
#                          'outstand_tbills': '35900',
#                          'preliminary': '0',
#                          'redempt_bonds': '0',
#                          'redempt_tbills': '30500',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2009-Q1',
#                          'issue_bonds': '4200',
#                          'issue_tbills': '35400',
#                          'outstand_bonds': '66900',
#                          'outstand_tbills': '41300',
#                          'preliminary': '0',
#                          'redempt_bonds': '6000',
#                          'redempt_tbills': '30000',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2009-Q2',
#                          'issue_bonds': '2800',
#                          'issue_tbills': '43200',
#                          'outstand_bonds': '69700',
#                          'outstand_tbills': '46000',
#                          'preliminary': '0',
#                          'redempt_bonds': '0',
#                          'redempt_tbills': '38500',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2009-Q3',
#                          'issue_bonds': '3600',
#                          'issue_tbills': '43200',
#                          'outstand_bonds': '73300',
#                          'outstand_tbills': '49300',
#                          'preliminary': '0',
#                          'redempt_bonds': '0',
#                          'redempt_tbills': '39900',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2009-Q4',
#                          'issue_bonds': '2200',
#                          'issue_tbills': '52200',
#                          'outstand_bonds': '71600',
#                          'outstand_tbills': '52100',
#                          'preliminary': '0',
#                          'redempt_bonds': '3900',
#                          'redempt_tbills': '49400',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2010-Q1',
#                          'issue_bonds': '3300',
#                          'issue_tbills': '41600',
#                          'outstand_bonds': '74900',
#                          'outstand_tbills': '51700',
#                          'preliminary': '0',
#                          'redempt_bonds': '0',
#                          'redempt_tbills': '42000',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2010-Q2',
#                          'issue_bonds': '4000',
#                          'issue_tbills': '49800',
#                          'outstand_bonds': '75000',
#                          'outstand_tbills': '53100',
#                          'preliminary': '0',
#                          'redempt_bonds': '3900',
#                          'redempt_tbills': '48400',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2010-Q3',
#                          'issue_bonds': '4500',
#                          'issue_tbills': '51200',
#                          'outstand_bonds': '73600',
#                          'outstand_tbills': '54500',
#                          'preliminary': '0',
#                          'redempt_bonds': '5900',
#                          'redempt_tbills': '49800',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2010-Q4',
#                          'issue_bonds': '1600',
#                          'issue_tbills': '53500',
#                          'outstand_bonds': '75200',
#                          'outstand_tbills': '57100',
#                          'preliminary': '0',
#                          'redempt_bonds': '0',
#                          'redempt_tbills': '50900',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2011-Q1',
#                          'issue_bonds': '4900',
#                          'issue_tbills': '50700',
#                          'outstand_bonds': '75400',
#                          'outstand_tbills': '57900',
#                          'preliminary': '0',
#                          'redempt_bonds': '4700',
#                          'redempt_tbills': '49900',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2011-Q2',
#                          'issue_bonds': '5200',
#                          'issue_tbills': '54300',
#                          'outstand_bonds': '80600',
#                          'outstand_tbills': '57900',
#                          'preliminary': '0',
#                          'redempt_bonds': '0',
#                          'redempt_tbills': '54300',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2011-Q3',
#                          'issue_bonds': '3800',
#                          'issue_tbills': '50700',
#                          'outstand_bonds': '77600',
#                          'outstand_tbills': '57900',
#                          'preliminary': '0',
#                          'redempt_bonds': '6800',
#                          'redempt_tbills': '50700',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2011-Q4',
#                          'issue_bonds': '1800',
#                          'issue_tbills': '55500',
#                          'outstand_bonds': '79400',
#                          'outstand_tbills': '59100',
#                          'preliminary': '0',
#                          'redempt_bonds': '0',
#                          'redempt_tbills': '54300',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2012-Q1',
#                          'issue_bonds': '5200',
#                          'issue_tbills': '52000',
#                          'outstand_bonds': '84600',
#                          'outstand_tbills': '59200',
#                          'preliminary': '0',
#                          'redempt_bonds': '0',
#                          'redempt_tbills': '51900',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2012-Q2',
#                          'issue_bonds': '3600',
#                          'issue_tbills': '56000',
#                          'outstand_bonds': '83100',
#                          'outstand_tbills': '59600',
#                          'preliminary': '0',
#                          'redempt_bonds': '5100',
#                          'redempt_tbills': '55600',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2012-Q3',
#                          'issue_bonds': '5600',
#                          'issue_tbills': '51000',
#                          'outstand_bonds': '85300',
#                          'outstand_tbills': '58600',
#                          'preliminary': '0',
#                          'redempt_bonds': '3400',
#                          'redempt_tbills': '52000',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2012-Q4',
#                          'issue_bonds': '2000',
#                          'issue_tbills': '44000',
#                          'outstand_bonds': '82600',
#                          'outstand_tbills': '60000',
#                          'preliminary': '0',
#                          'redempt_bonds': '4700',
#                          'redempt_tbills': '42600',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2013-Q1',
#                          'issue_bonds': '4100',
#                          'issue_tbills': '38000',
#                          'outstand_bonds': '86700',
#                          'outstand_tbills': '60000',
#                          'preliminary': '0',
#                          'redempt_bonds': '0',
#                          'redempt_tbills': '38000',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2013-Q2',
#                          'issue_bonds': '4700',
#                          'issue_tbills': '35600',
#                          'outstand_bonds': '86200',
#                          'outstand_tbills': '51600',
#                          'preliminary': '0',
#                          'redempt_bonds': '5200',
#                          'redempt_tbills': '44000',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2013-Q3',
#                          'issue_bonds': '3500',
#                          'issue_tbills': '16800',
#                          'outstand_bonds': '83500',
#                          'outstand_tbills': '44400',
#                          'preliminary': '0',
#                          'redempt_bonds': '6200',
#                          'redempt_tbills': '24000',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2013-Q4',
#                          'issue_bonds': '2500',
#                          'issue_tbills': '18000',
#                          'outstand_bonds': '86000',
#                          'outstand_tbills': '38800',
#                          'preliminary': '0',
#                          'redempt_bonds': '0',
#                          'redempt_tbills': '23600',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2014-Q1',
#                          'issue_bonds': '3800',
#                          'issue_tbills': '0',
#                          'outstand_bonds': '86900',
#                          'outstand_tbills': '22000',
#                          'preliminary': '0',
#                          'redempt_bonds': '2900',
#                          'redempt_tbills': '16800',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2014-Q2',
#                          'issue_bonds': '5300',
#                          'issue_tbills': '4000',
#                          'outstand_bonds': '92200',
#                          'outstand_tbills': '8000',
#                          'preliminary': '0',
#                          'redempt_bonds': '0',
#                          'redempt_tbills': '18000',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2014-Q3',
#                          'issue_bonds': '6800',
#                          'issue_tbills': '0',
#                          'outstand_bonds': '93200',
#                          'outstand_tbills': '8000',
#                          'preliminary': '0',
#                          'redempt_bonds': '5800',
#                          'redempt_tbills': '0',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2014-Q4',
#                          'issue_bonds': '2900',
#                          'issue_tbills': '4000',
#                          'outstand_bonds': '90100',
#                          'outstand_tbills': '8000',
#                          'preliminary': '0',
#                          'redempt_bonds': '6000',
#                          'redempt_tbills': '4000',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2015-Q1',
#                          'issue_bonds': '4800',
#                          'issue_tbills': '0',
#                          'outstand_bonds': '92000',
#                          'outstand_tbills': '8000',
#                          'preliminary': '0',
#                          'redempt_bonds': '2900',
#                          'redempt_tbills': '0',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2015-Q2',
#                          'issue_bonds': '5100',
#                          'issue_tbills': '4200',
#                          'outstand_bonds': '97100',
#                          'outstand_tbills': '8200',
#                          'preliminary': '0',
#                          'redempt_bonds': '0',
#                          'redempt_tbills': '4000',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2015-Q3',
#                          'issue_bonds': '3900',
#                          'issue_tbills': '0',
#                          'outstand_bonds': '94700',
#                          'outstand_tbills': '8200',
#                          'preliminary': '0',
#                          'redempt_bonds': '6300',
#                          'redempt_tbills': '0',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2015-Q4',
#                          'issue_bonds': '2500',
#                          'issue_tbills': '4300',
#                          'outstand_bonds': '97200',
#                          'outstand_tbills': '8500',
#                          'preliminary': '0',
#                          'redempt_bonds': '0',
#                          'redempt_tbills': '4000',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2016-Q1',
#                          'issue_bonds': '4100',
#                          'issue_tbills': '0',
#                          'outstand_bonds': '101300',
#                          'outstand_tbills': '8500',
#                          'preliminary': '0',
#                          'redempt_bonds': '0',
#                          'redempt_tbills': '0',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2016-Q2',
#                          'issue_bonds': '6400',
#                          'issue_tbills': '4500',
#                          'outstand_bonds': '100400',
#                          'outstand_tbills': '8800',
#                          'preliminary': '0',
#                          'redempt_bonds': '7300',
#                          'redempt_tbills': '4200',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2016-Q3',
#                          'issue_bonds': '5500',
#                          'issue_tbills': '0',
#                          'outstand_bonds': '98200',
#                          'outstand_tbills': '8800',
#                          'preliminary': '0',
#                          'redempt_bonds': '7700',
#                          'redempt_tbills': '0',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2016-Q4',
#                          'issue_bonds': '2800',
#                          'issue_tbills': '4500',
#                          'outstand_bonds': '101000',
#                          'outstand_tbills': '9000',
#                          'preliminary': '0',
#                          'redempt_bonds': '0',
#                          'redempt_tbills': '4300',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2017-Q1',
#                          'issue_bonds': '4600',
#                          'issue_tbills': '2200',
#                          'outstand_bonds': '105600',
#                          'outstand_tbills': '11200',
#                          'preliminary': '0',
#                          'redempt_bonds': '0',
#                          'redempt_tbills': '0',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2017-Q2',
#                          'issue_bonds': '4900',
#                          'issue_tbills': '2500',
#                          'outstand_bonds': '103000',
#                          'outstand_tbills': '9200',
#                          'preliminary': '0',
#                          'redempt_bonds': '7500',
#                          'redempt_tbills': '4500',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2017-Q3',
#                          'issue_bonds': '2600',
#                          'issue_tbills': '2300',
#                          'outstand_bonds': '105600',
#                          'outstand_tbills': '11500',
#                          'preliminary': '0',
#                          'redempt_bonds': '0',
#                          'redempt_tbills': '0',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2017-Q4',
#                          'issue_bonds': '3400',
#                          'issue_tbills': '2500',
#                          'outstand_bonds': '106500',
#                          'outstand_tbills': '9500',
#                          'preliminary': '0',
#                          'redempt_bonds': '2500',
#                          'redempt_tbills': '4500',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2018-Q1',
#                          'issue_bonds': '4600',
#                          'issue_tbills': '2500',
#                          'outstand_bonds': '111100',
#                          'outstand_tbills': '9800',
#                          'preliminary': '0',
#                          'redempt_bonds': '0',
#                          'redempt_tbills': '2200',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2018-Q2',
#                          'issue_bonds': '8700',
#                          'issue_tbills': '2600',
#                          'outstand_bonds': '113100',
#                          'outstand_tbills': '9900',
#                          'preliminary': '0',
#                          'redempt_bonds': '6700',
#                          'redempt_tbills': '2500',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2018-Q3',
#                          'issue_bonds': '5900',
#                          'issue_tbills': '2500',
#                          'outstand_bonds': '112200',
#                          'outstand_tbills': '10100',
#                          'preliminary': '0',
#                          'redempt_bonds': '6800',
#                          'redempt_tbills': '2300',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2018-Q4',
#                          'issue_bonds': '2500',
#                          'issue_tbills': '2600',
#                          'outstand_bonds': '114700',
#                          'outstand_tbills': '10200',
#                          'preliminary': '0',
#                          'redempt_bonds': '0',
#                          'redempt_tbills': '2500',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2019-Q1',
#                          'issue_bonds': '4500',
#                          'issue_tbills': '2700',
#                          'outstand_bonds': '119200',
#                          'outstand_tbills': '10400',
#                          'preliminary': '0',
#                          'redempt_bonds': '0',
#                          'redempt_tbills': '2500',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2019-Q2',
#                          'issue_bonds': '8200',
#                          'issue_tbills': '2800',
#                          'outstand_bonds': '118700',
#                          'outstand_tbills': '10600',
#                          'preliminary': '0',
#                          'redempt_bonds': '8700',
#                          'redempt_tbills': '2600',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2019-Q3',
#                          'issue_bonds': '7100',
#                          'issue_tbills': '28700',
#                          'outstand_bonds': '125800',
#                          'outstand_tbills': '36800',
#                          'preliminary': '0',
#                          'redempt_bonds': '0',
#                          'redempt_tbills': '2500',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2019-Q4',
#                          'issue_bonds': '5200',
#                          'issue_tbills': '28300',
#                          'outstand_bonds': '123900',
#                          'outstand_tbills': '58800',
#                          'preliminary': '0',
#                          'redempt_bonds': '7100',
#                          'redempt_tbills': '6300',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2020-Q1',
#                          'issue_bonds': '4800',
#                          'issue_tbills': '25200',
#                          'outstand_bonds': '128700',
#                          'outstand_tbills': '59000',
#                          'preliminary': '0',
#                          'redempt_bonds': '0',
#                          'redempt_tbills': '25000',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2020-Q2',
#                          'issue_bonds': '6500',
#                          'issue_tbills': '28700',
#                          'outstand_bonds': '135200',
#                          'outstand_tbills': '59400',
#                          'preliminary': '0',
#                          'redempt_bonds': '0',
#                          'redempt_tbills': '28300',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2020-Q3',
#                          'issue_bonds': '9900',
#                          'issue_tbills': '25300',
#                          'outstand_bonds': '131600',
#                          'outstand_tbills': '59700',
#                          'preliminary': '0',
#                          'redempt_bonds': '13500',
#                          'redempt_tbills': '25000',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2020-Q4',
#                          'issue_bonds': '4700',
#                          'issue_tbills': '28800',
#                          'outstand_bonds': '136300',
#                          'outstand_tbills': '60000',
#                          'preliminary': '0',
#                          'redempt_bonds': '0',
#                          'redempt_tbills': '28500',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2021-Q1',
#                          'issue_bonds': '5900',
#                          'issue_tbills': '26300',
#                          'outstand_bonds': '142200',
#                          'outstand_tbills': '61000',
#                          'preliminary': '0',
#                          'redempt_bonds': '0',
#                          'redempt_tbills': '25300',
#                          'timestamp': '1675546874'},
#                         {'end_of_quarter': '2021-Q2',
#                          'issue_bonds': '8500',
#                          'issue_tbills': '31800',
#                          'outstand_bonds': '142700',
#                          'outstand_tbills': '64000',
#                          'preliminary': '0',
#                          'redempt_bonds': '8000',
#                          'redempt_tbills': '28800',
#                          'timestamp': '1675546874'}],
#             'resource_id': ['ec2cb157-d25f-4245-a547-dc036b321a09'],
#             'total': '122'},
#  'success': True}

# %%
import pandas as pd

sg_treasury = pd.json_normalize(response.json()['result'] ['records'])
sg_treasury.head()
# Out:
#   end_of_quarter preliminary issue_tbills issue_bonds redempt_tbills  \
# 0        1991-Q1           0         2410        1050           1770
# 1        1991-Q2           0         2200         450           1960
# 2        1991-Q3           0         2290         800           2050
# 3        1991-Q4           0         2660           0           2380
# 4        1992-Q1           0         3210         850           2760
#
#   redempt_bonds outstand_tbills outstand_bonds   timestamp
# 0             0            2710           7660  1675546874
# 1           500            2950           7610  1675546874
# 2           700            3190           7710  1675546874
# 3             0            3470           7710  1675546874
# 4           650            3920           7910  1675546874

# %%
# group by year
sg_treasury['year'] = pd.DatetimeIndex(sg_treasury['end_of_quarter']).year
sg_treasury = sg_treasury.groupby('year').sum()
sg_treasury = sg_treasury.drop(columns=['end_of_quarter', 'preliminary', 'timestamp'])
sg_treasury.head()
# Out:
#           issue_tbills     issue_bonds    redempt_tbills  redempt_bonds  \
# year
# 1991  2410220022902660     10504508000  1770196020502380       05007000
# 1992  3210280039403940   8507007001450  2760255031703940  6505003001200
# 1993  3520389049903810   8305501350530  3740402048903510      530010300
# 1994  4220355042404120   8507508001350  4160364046603660    85060001650
# 1995  5110467047905400  10508001750600  5000399047905440      055019500
#
#        outstand_tbills        outstand_bonds
# year
# 1991  2710295031903470      7660761077107710
# 1992  3920417049404940      7910811085108760
# 1993  4720459046904990     90609610993010460
# 1994  5050496045405000  10460106101141011110
# 1995  5110579057905750  12160124101221012810

# %%
import os
os.makedirs('C:/Users/James/OneDrive - Nanyang Technological University/GitHub/US treasury', exist_ok=True)
sg_treasury.to_csv('C:/Users/James/OneDrive - Nanyang Technological University/GitHub/US treasury/sg_treasury.csv')
